# %%
from test import *
from benchmark import benchmark

# %%
check_tasks()
# Out:
# Checks passed

# %%
benchmark()
# Out:
# Method: naive, time: 1.4256111999999996
# Method: simple, time: 0.018942200000000575
# Method: cohen, time: 0.015744600000000553
# Method: sandia, time: 0.014318099999999667
# ______________
# Method: naive, time: 3.3387449
# Method: simple, time: 0.06721680000000063
# Method: cohen, time: 0.04431459999999987
# Method: sandia, time: 0.03508910000000043
# ______________
# Method: naive, time: 3.759978199999999
# Method: simple, time: 0.02796640000000039
# Method: cohen, time: 0.03150419999999876
# Method: sandia, time: 0.024515799999999643
# ______________
# Method: naive, time: 5.3437907
# Method: simple, time: 0.07960669999999936
# Method: cohen, time: 0.05912079999999875
# Method: sandia, time: 0.037595299999999554
# ______________
# Method: naive, time: 0.9618330000000022
# Method: simple, time: 0.02236130000000003
# Method: cohen, time: 0.017582599999997228
# Method: sandia, time: 0.014462999999999226
# ______________
# Method: naive, time: 0.23825120000000055
# ...

# %% [markdown]
# Как видно из графиков -- наивный подход с 3 умножениями значительно уступает в скорости остальным алгоритмам.
# Остальные алгоритмы имеют одинаковый порядок времени исполнения. Однако почти во всех случаях simple < cohen < sandia. Также отметим здесь, что нет четкой зависимости времени исполнения от размера матрицы (есть у другие параметры, такие как разреженность)
